# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import string
from nltk.corpus import stopwords

from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
url = 'http://destroyblackmagic.com/quran/data/id.indonesian.json'
df = pd.read_json(url)

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#                                                            quran
# id.indonesian  {'1': {'surah': 1, 'ayah': 1, 'verse': 'Dengan...

# %%
data = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-indonesia/surah/1.json')

# %%
data.head()
# Out:
#                                                                 1
# name                                                      الفاتحة
# name_latin                                             Al-Fatihah
# number                                                          1
# number_of_ayah                                                  7
# tafsir          {'id': {'kemenag': {'name': 'Kemenag', 'source...

# %%
data = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-english/en_translation_1.json')

# %%
data6= pd.read_csv('https://raw.githubusercontent.com/langsari/quran-dataset/master/notebook/eda/Suraiya-Project/English.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb4 in position 26: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-6be930021586> in <module>
# ----> 1 data6= pd.read_csv('https://raw.githubusercontent.com/langsari/quran-dataset/master/notebook/eda/Suraiya-Project/English.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb4 in position 26: invalid start byte

# %%
data
# Out:
#                name  index                                              verse  \
# verse_1  al-Fatihah      1    In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1              Praise be to God, Lord of the Worlds.
# verse_3  al-Fatihah      1              The Most Gracious, the Most Merciful.
# verse_4  al-Fatihah      1                     Master of the Day of Judgment.
# verse_5  al-Fatihah      1  It is You we worship, and upon You we call for...
# verse_6  al-Fatihah      1                     Guide us to the straight path.
# verse_7  al-Fatihah      1  The path of those You have blessed, not of tho...
#
#          count
# verse_1      7
# verse_2      7
# verse_3      7
# verse_4      7
# verse_5      7
# verse_6      7
# verse_7      7

# %%
url = 'http://destroyblackmagic.com/quran/data/id.indonesian.json'
df = pd.read_json(url)
df
# Out:
#                                                            quran
# id.indonesian  {'1': {'surah': 1, 'ayah': 1, 'verse': 'Dengan...

# %%
df
# Out:
#                                                            quran
# id.indonesian  {'1': {'surah': 1, 'ayah': 1, 'verse': 'Dengan...

# %%
conda install -c anaconda beautifulsoup4
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://quran.com/1"

# %%
web_data = requests.get(url)

# %%
print(web_data.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="QC7Xz/JqEi1jbKmC51/v9IlI5V8ioGzQd2+XJal36XyWpgPA6NuyU5W2sO2oZ4wtD6fLxiKOxTaBraa/NIH54Q==" />
#     <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta property="og:locale" content="en">
# <meta name="distribution" content="Global"/>
#
# <link href="https://cdn.qurancdn.com" rel="preconnect" crossorigin>
# <link href="https://audio.qurancdn.com" rel="preconnect" crossorigin>
#
# <link rel="manifest" href="/static/manifest.json">
# <link rel="search" type="application/opensearchdescription+xml" title="search Quran.com" href="/static/opensearch.xml">
#
# <link href="https://cdn.qurancdn.com/assets/icons/favicon-635c941756e3890ae66f538ad87176d12827fc35ee46d958d4b2c86cfc485c11.ico" title="Quran.com" type="image/x-icon" rel="shortcut icon" />
# <link href="https://cdn.qurancdn.com/assets/icons/android-chrome-256x256-5ce92ae50dbe024515dae5d9b6e5ca249b8f327018630846c35d0c780a41769b.png" title="Quran.com" type="image/png" rel="fluid-icon" />
# <link href="https://cdn.qurancdn.com/assets/icons/safari-pinned-tab-30c3f649aa7fe0283339acba891f14f701244454a41be4e5cbf4045bbb5728ea.svg" title="Quran.com" type="image/x-icon" rel="mask-icon" color="theme-color" />
# <link href="https://cdn.qurancdn.com/assets/icons/apple-touch-icon-2a7c9837b14d7ff52d75d814e88ad221c593174ede7cd60f2efa8c6aa6e87f97.png" title="Quran.com" type="image/png" rel="apple-touch-icon" color="theme-color" />
#
#
# <title>Surah Al-Fatihah - 1:1 | Quran.com</title>
# <meta name="description" content="Surah Al-Fatihah(الفاتحة) 1:1 In the Name of Allah—the Most Compassionate, Most Merciful.">
# <meta name="keywords" content="سورة الفاتحة, the opener, সূচনা, pembukaan, അല്‍ഫാതിഹ, pristup, de opening, открывающая коран, la apertura, öppningen, 开端章, l&#39;ouverture, کھولنے والی, kitabı açan, fâtiha, l’aprente, القران الكريم, القرآن, قران, quran">
# <link rel="canonical" href="https://quran.com/1">
# <meta property="og:title" content="Surah Al-Fatihah - 1:1">
# <meta property="og:description" content="Surah Al-Fatihah(الفاتحة) 1:1 In the Name of Allah—the Most Compassionate, Most Merciful.">
# <meta property="og:url" content="https://quran.com/1/1?translations=131">
# <meta property="og:type" content="article">
# <meta property="og:image" content="https://quran-og-image.vercel.app/1/1">
# <meta property="og:image:alt" content="Quran.com">
# <meta property="al:web:url" content="https://quran.com/1/1?translations=131">
# <meta property="al:ios:url" content="https://itunes.apple.com/us/app/quran-by-quran.com-qran/id1118663303">
# <meta property="al:ios:app_store_id" content="1118663303">
# <meta property="al:ios:app_name" content="Quran - by Quran.com - قرآن">
# <meta property="al:android:url" content="https://play.google.com/store/apps/details?id=com.quran.labs.androidquran">
# <meta property="al:android:app_name" content="Quran for Android">
# <meta property="al:android:package" content="com.quran.labs.androidquran">
# <meta name="twitter:creator" content="@app_quran">
# <meta name="twitter:site" content="@app_auran">
# <meta name="twitter:card" content="summary_large_image">
# <meta property="fb:app_id" content="342185219529773">
# <meta property="fb:pages" content="603289706669016">
# <meta property="fb:article_style" content="quran">
# <meta name="image" content="https://quran-og-image.vercel.app/1/1">
# <meta name="apple-itunes-app" content="app-id=1118663303">
# <meta name="google" content="notranslate" />
#
# <meta property="og:rich_attachment"     content="true">
# <meta name="twitter:card" content="summary_large_image">
# <meta name="twitter:site" content="@Quran">
# <meta name="twitter:creator" content="@Quran">
#
# <meta name="theme-color" content="#00acc1">
# <meta name="mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-title" content="Quran.com">
# <meta name="MobileOptimized" content="width" />
# <meta name="HandheldFriendly" content="true" />
# <meta name="format-detection" content="telephone=no">
# <meta name="apple-mobile-web-app-status-bar-style" content="black">
# <meta name="application-name" content="Quran.com" />
# <meta name="msapplication-TileImage" content="https://cdn.qurancdn.com/assets/icons/apple-touch-icon-2a7c9837b14d7ff52d75d814e88ad221c593174ede7cd60f2efa8c6aa6e87f97.png">
# <meta name="msapplication-TileColor" content="#00acc1">
# <meta name="msapplication-config" content="http://quran.com/static/msapplication_config.xml">
# <meta name="msapplication-tooltip" content="Quran.com" />
# <meta name="msapplication-starturl" content="https://www.quran.com" />
# <meta name="msapplication-navbutton-color" content="#00acc1" />
# <meta name="rating" content="General">
# <meta name="robots" content="all, index, follow, archive">
# <meta name="revisit-after" content="30 days">
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-8496014-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#     gtag('js', new Date());
#     gtag('config', 'UA-8496014-1');
#     document.addEventListener('turbolinks:load', function (event) {
#         if (typeof gtag === 'function') {
#             gtag('config', 'UA-8496014-1', {
#                 'page_location': event.data.url
#             });
#         }
#     });
# </script>
#
# <script defer src="https://polyfill.io/v3/polyfill.min.js?features=es6%2CPromise%2Csmoothscroll%2Cdefault%2Ces2015%2Ces2018%2Cfetch%2CMutationObserver%2CIntersectionObserver%2CIntersectionObserverEntry&flags=gated"></script>
#
#     <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js" defer></script>
#     <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js defer"></script>
#     <![endif]-->
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.2.0/lazysizes.min.js" async></script>
#     <link rel="stylesheet" media="all" href="https://cdn.qurancdn.com/packs/css/application-0e5b44f7.chunk.css" data-turbolinks-track="reload" />
#     <link rel="stylesheet" media="all" href="https://cdn.qurancdn.com/assets/font-faces-4029fbc995e4c1c7a712d41a5221fa6f2c68bf2ce2a3674da85040fc32f2dd4f.css" data-turbolinks-track="reload" />
#     <script src="https://cdn.qurancdn.com/packs/js/runtime~application-f1e5e75347851cd5a270.js" data-turbolinks-track="reload" defer="defer"></script>
# <script src="https://cdn.qurancdn.com/packs/js/vendors~application-5bf34228478974fd9125.chunk.js" data-turbolinks-track="reload" defer="defer"></script>
# <script src="https://cdn.qurancdn.com/packs/js/application-658c8078a8c615f6d465.chunk.js" data-turbolinks-track="reload" defer="defer"></script>
#   </head>
#
#   <body class="chapters show lang-en" id="chapters-show" data-controller="setting spinner">
#   <script>
#       window.locale = 'en';
#   </script>
#     <noscript>
#       <div class="row">
#         Looks like either your browser does not support Javascript or its disabled. For a better
#         Quran.com experience, please enable JavaScript in your browser.
#         For more instruction on how to enable javascript
#         <a href="http://www.enable-javascript.com/" target="_blank" rel="nofollow">
#           click here
#         </a>.
#       </div>
#     </noscript>
#     <div id='left-sidebar' class="sidebar slide-left border-right d-none">
#   <div class="sidebar-head d-flex align-items-center">
#     <h4 class="ff-b mb-0">Menu</h4>
#     <i class="fa fa-times-circle close-sidebar close-left-sidebar text-muted"></i>
#   </div>
#
#   <ul class="main-menu p-0">
#     <li class="d-block my-1">
#       <a href="/">
#         <i class="fa fa-home pr-2"></i>
#         <span class='en'>Home</span>
# </a>    </li>
#     <li class="d-block my-1">
#       <a href="/about-us">
#         <i class="fa fa-info-circle pr-2"></i>
#          <span class='en'>About us</span>
# </a>    </li>
#     <li class="d-block my-1">
#       <a href="/donations">
#         <i class="fa fa-donate pr-2"></i>
#         <span class='en'>Contribute</span>
# </a>    </li>
#     <li class="d-block my-1">
#       <a href="/support">
#         <i class="fa fa-help pr-2"></i>
#
#         <span class='en'>Help & feedback</span>
# </a>    </li>
#     <li class="d-block my-1">
#       <a href="/developers">
#         <i class="fa fa-developer pr-2"></i>
#
#         <span class='en'>Developers</span>
# </a>    </li>
#     <li class="d-block my-1">
#       <a href="/apps">
#         <i class="fa fa-mobile pr-2"></i>
#         <span class='en'>Mobile Apps</span>
# </a>    </li>
#   </ul>
#
#   <div class="more-links">
#     <h4 class="ff-b"><span class='en'>Related Sites</span></h4>
#     <ul class="p-0">
#       <li class="d-block my-1">
#         <a href="https://quranicaudio.com/" target="_blank" rel="noopener noreferrer">Quraninaudio.com</a>
#       </li>
#       <li class="d-block my-1">
#         <a href="https://salah.com/" target="_blank" rel="noopener noreferrer">Salah.com</a>
#       </li>
#       <li class="d-block my-1">
#         <a href="https://sunnah.com/" target="_blank" rel="noopener noreferrer">Sunnah.com</a>
#       </li>
#       <li class="d-block my-1">
#         <a href="https://legacy.quran.com/" target="_blank" rel="noopener noreferrer"> Legacy Quran.com</a>
#       </li>
#       <li class="d-block my-1">
#         <a href="https://corpus.quran.com/wordbyword.jsp" target="_blank" rel="noopener noreferrer">Corpus.Quran.com</a>
#       </li>
#     </ul>
#   </div>
# </div>
#
# <div class="slide-backdrop close-left-sidebar">
# </div>
#
#
# <header class="sticky-top">
#   <nav class="navbar navbar-light bg-white custom-shadow">
#     <div class="container">
#       <div class="row">
#         <div class="col d-flex align-items-center">
#           <button class="navbar-toggler" type="button" data-controller="sidebar" data-target="#left-sidebar" data-close=".close-left-sidebar">
#             <i class="fa fa-bars-regular"></i>
#           </button>
#
#           <a class="h2 ff-b mb-0 ml-3" href="/">
#             Quran<span class="ff-m h4 ml-0">.com</span>
# </a>
#           <div id="local-switcher" class="d-md-block">
#             <div class="dropdown">
#               <a class="nav-link dropdown-toggle pb-0" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                 <span class='en'>English</span> <i class="fa fa-fadown-open"></i>
#               </a>
#
#               <ul class="dropdown-menu">
#                   <li>
#                     <a class="dropdown-item active" href="/1?locale=en">
#                       <span class="en">English</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=ur">
#                       <span class="ur">اردو</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=ar">
#                       <span class="ar">العربية</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=bn">
#                       <span class="bn">বাংলা</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=fa">
#                       <span class="fa">فارسی</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=fr">
#                       <span class="fr">Français</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=id">
#                       <span class="id">Indonesia</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=it">
#                       <span class="it">Italiano</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=nl">
#                       <span class="nl">Nederlands</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=pt">
#                       <span class="pt">Português</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=sq">
#                       <span class="sq">Shqip</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=th">
#                       <span class="th">ภาษาไทย</span>
# </a>                  </li>
#                   <li>
#                     <a class="dropdown-item " href="/1?locale=tr">
#                       <span class="tr">Türkçe</span>
# </a>                  </li>
#               </ul>
#             </div>
#           </div>
#         </div>
#
#           <div class="col-2 col-md-8 align-items-center chapter-header">
#     <div class="rounded-search col-md-6">
#
# <div class="search-form flex-fill">
#   <form class="form-search form-group" action="/search" data-controller="search-form" data-expand=true>
#     <input class="form-control bg-light en" placeholder="Search &quot;Noah&quot;" type="search" name="query" value="">
#     <button type="submit" class="form-control form-control-submit search-btn"></button>
#
#     <span class="search-label rounded-right" id=search-trigger>
#       <i class="fa fa-search"></i>
#     </span>
#     <div class="suggestions"></div>
#   </form>
# </div>
#
#     </div>
#   </div>
#
#       </div>
#     </div>
#   </nav>
# </header>
#
#
#     <main data-controller="theme">
#
# <div id="right-sidebar" class="sidebar slide-right border-left d-none">
#   <div class="sidebar-head d-flex align-items-center justify-content-between">
#     <i class="fa fa-times-circle close-sidebar close-right-sidebar text-muted"></i>
#     <h6 class="mb-0 ff-b"><span class='en'>Settings</span></h6>
#
#     <button class="btn btn-primary text-white" id='reset-settings'><span class='en'>Reset to default</span></button>
#   </div>
#
#   <div class="bg-faded outline" style="margin-top: -7px">
#
# <div class="render-async  " id="render_async_fd230279f61606535251" data-path="/settings?chapter=1" data-method="GET" data-headers="{}" data-lazy-load="{&quot;root&quot;:&quot;#right-sidebar&quot;}" data-controller="render-async">
#
#       <p class="text-center p-3">
#         <i class='fa fa-spinner fa-spin'></i> <span class='en'>Loading...</span>
#       </p>
#
# </div>  </div>
# </div>
#
# <div class="slide-backdrop close-right-sidebar">
# </div>
#
# <div id="chapter-page">
#
# <section class="bg-info surah-actions sticky-top">
#   <div class="container position-relative">
#     <div class="row align-items-center actions-row">
#       <div class="col-md-2 col-5">
#         <div class="dropdown surah-dropdown">
#           <button class="btn btn-white dropdown-toggle position-relative" type="button" id="dropdownMenuButton" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#             <div class="text-left pr-3 text-primary">
#               <strong>
#                 Al-Fatihah
#               </strong>
#               <p class="text-muted mb-0">The Opener</p>
#             </div>
#           </button>
#
#           <div
#             class="dropdown-menu border-0 custom-shadow pt-0"
#             aria-labelledby="dropdownMenuButton"
#             data-controller="filter-list"
#             data-list="#chapters"
#             data-input="#filter-chapter"
#           >
#             <div class="d-flex justify-content-between align-items-center p-3 border-bottom d-md-none">
#               <h6 class="mb-0 ff-b text-primary"><span class='en'>Select Surah</span></h6>
#               <i class="fa fa-times-circle fa-center c-pointer text-muted"></i>
#             </div>
#
#             <div class="rounded-search pt-3 mb-3 px-2">
#               <input class="form-control bg-light px-2" type="search" id="filter-chapter"/>
#             </div>
#
#             <div id=chapters>
#                 <div class="dropdown-item active" data-filter-tags="1 al-fatihah the opener الفاتحة">
#                   <a href="/1">
#                     <div class='row'>
#                       <div class="col-2">1</div>
#                       <div class="col-7 text-muted">
#                         Al-Fatihah
#                       </div>
#                       <div class="col-3">
#                         الفاتحة
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Opener
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="2 al-baqarah the cow البقرة">
#                   <a href="/2">
#                     <div class='row'>
#                       <div class="col-2">2</div>
#                       <div class="col-7 text-muted">
#                         Al-Baqarah
#                       </div>
#                       <div class="col-3">
#                         البقرة
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Cow
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="3 ali &#39;imran family of imran آل عمران">
#                   <a href="/3">
#                     <div class='row'>
#                       <div class="col-2">3</div>
#                       <div class="col-7 text-muted">
#                         Ali &#39;Imran
#                       </div>
#                       <div class="col-3">
#                         آل عمران
#                       </div>
#                       <div class="col-10 offset-2">
#                         Family of Imran
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="4 an-nisa the women النساء">
#                   <a href="/4">
#                     <div class='row'>
#                       <div class="col-2">4</div>
#                       <div class="col-7 text-muted">
#                         An-Nisa
#                       </div>
#                       <div class="col-3">
#                         النساء
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Women
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="5 al-ma&#39;idah the table spread المائدة">
#                   <a href="/5">
#                     <div class='row'>
#                       <div class="col-2">5</div>
#                       <div class="col-7 text-muted">
#                         Al-Ma&#39;idah
#                       </div>
#                       <div class="col-3">
#                         المائدة
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Table Spread
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="6 al-an&#39;am the cattle الأنعام">
#                   <a href="/6">
#                     <div class='row'>
#                       <div class="col-2">6</div>
#                       <div class="col-7 text-muted">
#                         Al-An&#39;am
#                       </div>
#                       <div class="col-3">
#                         الأنعام
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Cattle
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="7 al-a&#39;raf the heights الأعراف">
#                   <a href="/7">
#                     <div class='row'>
#                       <div class="col-2">7</div>
#                       <div class="col-7 text-muted">
#                         Al-A&#39;raf
#                       </div>
#                       <div class="col-3">
#                         الأعراف
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Heights
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="8 al-anfal the spoils of war الأنفال">
#                   <a href="/8">
#                     <div class='row'>
#                       <div class="col-2">8</div>
#                       <div class="col-7 text-muted">
#                         Al-Anfal
#                       </div>
#                       <div class="col-3">
#                         الأنفال
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Spoils of War
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="9 at-tawbah the repentance التوبة">
#                   <a href="/9">
#                     <div class='row'>
#                       <div class="col-2">9</div>
#                       <div class="col-7 text-muted">
#                         At-Tawbah
#                       </div>
#                       <div class="col-3">
#                         التوبة
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Repentance
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="10 yunus jonah يونس">
#                   <a href="/10">
#                     <div class='row'>
#                       <div class="col-2">10</div>
#                       <div class="col-7 text-muted">
#                         Yunus
#                       </div>
#                       <div class="col-3">
#                         يونس
#                       </div>
#                       <div class="col-10 offset-2">
#                         Jonah
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="11 hud hud هود">
#                   <a href="/11">
#                     <div class='row'>
#                       <div class="col-2">11</div>
#                       <div class="col-7 text-muted">
#                         Hud
#                       </div>
#                       <div class="col-3">
#                         هود
#                       </div>
#                       <div class="col-10 offset-2">
#                         Hud
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="12 yusuf joseph يوسف">
#                   <a href="/12">
#                     <div class='row'>
#                       <div class="col-2">12</div>
#                       <div class="col-7 text-muted">
#                         Yusuf
#                       </div>
#                       <div class="col-3">
#                         يوسف
#                       </div>
#                       <div class="col-10 offset-2">
#                         Joseph
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="13 ar-ra&#39;d the thunder الرعد">
#                   <a href="/13">
#                     <div class='row'>
#                       <div class="col-2">13</div>
#                       <div class="col-7 text-muted">
#                         Ar-Ra&#39;d
#                       </div>
#                       <div class="col-3">
#                         الرعد
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Thunder
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="14 ibrahim abraham ابراهيم">
#                   <a href="/14">
#                     <div class='row'>
#                       <div class="col-2">14</div>
#                       <div class="col-7 text-muted">
#                         Ibrahim
#                       </div>
#                       <div class="col-3">
#                         ابراهيم
#                       </div>
#                       <div class="col-10 offset-2">
#                         Abraham
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="15 al-hijr the rocky tract الحجر">
#                   <a href="/15">
#                     <div class='row'>
#                       <div class="col-2">15</div>
#                       <div class="col-7 text-muted">
#                         Al-Hijr
#                       </div>
#                       <div class="col-3">
#                         الحجر
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Rocky Tract
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="16 an-nahl the bee النحل">
#                   <a href="/16">
#                     <div class='row'>
#                       <div class="col-2">16</div>
#                       <div class="col-7 text-muted">
#                         An-Nahl
#                       </div>
#                       <div class="col-3">
#                         النحل
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Bee
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="17 al-isra the night journey الإسراء">
#                   <a href="/17">
#                     <div class='row'>
#                       <div class="col-2">17</div>
#                       <div class="col-7 text-muted">
#                         Al-Isra
#                       </div>
#                       <div class="col-3">
#                         الإسراء
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Night Journey
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="18 al-kahf the cave الكهف">
#                   <a href="/18">
#                     <div class='row'>
#                       <div class="col-2">18</div>
#                       <div class="col-7 text-muted">
#                         Al-Kahf
#                       </div>
#                       <div class="col-3">
#                         الكهف
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Cave
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="19 maryam mary مريم">
#                   <a href="/19">
#                     <div class='row'>
#                       <div class="col-2">19</div>
#                       <div class="col-7 text-muted">
#                         Maryam
#                       </div>
#                       <div class="col-3">
#                         مريم
#                       </div>
#                       <div class="col-10 offset-2">
#                         Mary
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="20 taha ta-ha طه">
#                   <a href="/20">
#                     <div class='row'>
#                       <div class="col-2">20</div>
#                       <div class="col-7 text-muted">
#                         Taha
#                       </div>
#                       <div class="col-3">
#                         طه
#                       </div>
#                       <div class="col-10 offset-2">
#                         Ta-Ha
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="21 al-anbya the prophets الأنبياء">
#                   <a href="/21">
#                     <div class='row'>
#                       <div class="col-2">21</div>
#                       <div class="col-7 text-muted">
#                         Al-Anbya
#                       </div>
#                       <div class="col-3">
#                         الأنبياء
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Prophets
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="22 al-hajj the pilgrimage الحج">
#                   <a href="/22">
#                     <div class='row'>
#                       <div class="col-2">22</div>
#                       <div class="col-7 text-muted">
#                         Al-Hajj
#                       </div>
#                       <div class="col-3">
#                         الحج
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Pilgrimage
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="23 al-mu&#39;minun the believers المؤمنون">
#                   <a href="/23">
#                     <div class='row'>
#                       <div class="col-2">23</div>
#                       <div class="col-7 text-muted">
#                         Al-Mu&#39;minun
#                       </div>
#                       <div class="col-3">
#                         المؤمنون
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Believers
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="24 an-nur the light النور">
#                   <a href="/24">
#                     <div class='row'>
#                       <div class="col-2">24</div>
#                       <div class="col-7 text-muted">
#                         An-Nur
#                       </div>
#                       <div class="col-3">
#                         النور
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Light
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="25 al-furqan the criterion الفرقان">
#                   <a href="/25">
#                     <div class='row'>
#                       <div class="col-2">25</div>
#                       <div class="col-7 text-muted">
#                         Al-Furqan
#                       </div>
#                       <div class="col-3">
#                         الفرقان
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Criterion
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="26 ash-shu&#39;ara the poets الشعراء">
#                   <a href="/26">
#                     <div class='row'>
#                       <div class="col-2">26</div>
#                       <div class="col-7 text-muted">
#                         Ash-Shu&#39;ara
#                       </div>
#                       <div class="col-3">
#                         الشعراء
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Poets
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="27 an-naml the ant النمل">
#                   <a href="/27">
#                     <div class='row'>
#                       <div class="col-2">27</div>
#                       <div class="col-7 text-muted">
#                         An-Naml
#                       </div>
#                       <div class="col-3">
#                         النمل
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Ant
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="28 al-qasas the stories القصص">
#                   <a href="/28">
#                     <div class='row'>
#                       <div class="col-2">28</div>
#                       <div class="col-7 text-muted">
#                         Al-Qasas
#                       </div>
#                       <div class="col-3">
#                         القصص
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Stories
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="29 al-&#39;ankabut the spider العنكبوت">
#                   <a href="/29">
#                     <div class='row'>
#                       <div class="col-2">29</div>
#                       <div class="col-7 text-muted">
#                         Al-&#39;Ankabut
#                       </div>
#                       <div class="col-3">
#                         العنكبوت
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Spider
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="30 ar-rum the romans الروم">
#                   <a href="/30">
#                     <div class='row'>
#                       <div class="col-2">30</div>
#                       <div class="col-7 text-muted">
#                         Ar-Rum
#                       </div>
#                       <div class="col-3">
#                         الروم
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Romans
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="31 luqman luqman لقمان">
#                   <a href="/31">
#                     <div class='row'>
#                       <div class="col-2">31</div>
#                       <div class="col-7 text-muted">
#                         Luqman
#                       </div>
#                       <div class="col-3">
#                         لقمان
#                       </div>
#                       <div class="col-10 offset-2">
#                         Luqman
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="32 as-sajdah the prostration السجدة">
#                   <a href="/32">
#                     <div class='row'>
#                       <div class="col-2">32</div>
#                       <div class="col-7 text-muted">
#                         As-Sajdah
#                       </div>
#                       <div class="col-3">
#                         السجدة
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Prostration
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="33 al-ahzab the combined forces الأحزاب">
#                   <a href="/33">
#                     <div class='row'>
#                       <div class="col-2">33</div>
#                       <div class="col-7 text-muted">
#                         Al-Ahzab
#                       </div>
#                       <div class="col-3">
#                         الأحزاب
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Combined Forces
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="34 saba sheba سبإ">
#                   <a href="/34">
#                     <div class='row'>
#                       <div class="col-2">34</div>
#                       <div class="col-7 text-muted">
#                         Saba
#                       </div>
#                       <div class="col-3">
#                         سبإ
#                       </div>
#                       <div class="col-10 offset-2">
#                         Sheba
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="35 fatir originator فاطر">
#                   <a href="/35">
#                     <div class='row'>
#                       <div class="col-2">35</div>
#                       <div class="col-7 text-muted">
#                         Fatir
#                       </div>
#                       <div class="col-3">
#                         فاطر
#                       </div>
#                       <div class="col-10 offset-2">
#                         Originator
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="36 ya-sin ya sin يس">
#                   <a href="/36">
#                     <div class='row'>
#                       <div class="col-2">36</div>
#                       <div class="col-7 text-muted">
#                         Ya-Sin
#                       </div>
#                       <div class="col-3">
#                         يس
#                       </div>
#                       <div class="col-10 offset-2">
#                         Ya Sin
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="37 as-saffat those who set the ranks الصافات">
#                   <a href="/37">
#                     <div class='row'>
#                       <div class="col-2">37</div>
#                       <div class="col-7 text-muted">
#                         As-Saffat
#                       </div>
#                       <div class="col-3">
#                         الصافات
#                       </div>
#                       <div class="col-10 offset-2">
#                         Those who set the Ranks
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="38 sad the letter &quot;saad&quot; ص">
#                   <a href="/38">
#                     <div class='row'>
#                       <div class="col-2">38</div>
#                       <div class="col-7 text-muted">
#                         Sad
#                       </div>
#                       <div class="col-3">
#                         ص
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Letter &quot;Saad&quot;
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="39 az-zumar the troops الزمر">
#                   <a href="/39">
#                     <div class='row'>
#                       <div class="col-2">39</div>
#                       <div class="col-7 text-muted">
#                         Az-Zumar
#                       </div>
#                       <div class="col-3">
#                         الزمر
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Troops
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="40 ghafir the forgiver غافر">
#                   <a href="/40">
#                     <div class='row'>
#                       <div class="col-2">40</div>
#                       <div class="col-7 text-muted">
#                         Ghafir
#                       </div>
#                       <div class="col-3">
#                         غافر
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Forgiver
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="41 fussilat explained in detail فصلت">
#                   <a href="/41">
#                     <div class='row'>
#                       <div class="col-2">41</div>
#                       <div class="col-7 text-muted">
#                         Fussilat
#                       </div>
#                       <div class="col-3">
#                         فصلت
#                       </div>
#                       <div class="col-10 offset-2">
#                         Explained in Detail
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="42 ash-shuraa the consultation الشورى">
#                   <a href="/42">
#                     <div class='row'>
#                       <div class="col-2">42</div>
#                       <div class="col-7 text-muted">
#                         Ash-Shuraa
#                       </div>
#                       <div class="col-3">
#                         الشورى
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Consultation
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="43 az-zukhruf the ornaments of gold الزخرف">
#                   <a href="/43">
#                     <div class='row'>
#                       <div class="col-2">43</div>
#                       <div class="col-7 text-muted">
#                         Az-Zukhruf
#                       </div>
#                       <div class="col-3">
#                         الزخرف
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Ornaments of Gold
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="44 ad-dukhan the smoke الدخان">
#                   <a href="/44">
#                     <div class='row'>
#                       <div class="col-2">44</div>
#                       <div class="col-7 text-muted">
#                         Ad-Dukhan
#                       </div>
#                       <div class="col-3">
#                         الدخان
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Smoke
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="45 al-jathiyah the crouching الجاثية">
#                   <a href="/45">
#                     <div class='row'>
#                       <div class="col-2">45</div>
#                       <div class="col-7 text-muted">
#                         Al-Jathiyah
#                       </div>
#                       <div class="col-3">
#                         الجاثية
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Crouching
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="46 al-ahqaf the wind-curved sandhills الأحقاف">
#                   <a href="/46">
#                     <div class='row'>
#                       <div class="col-2">46</div>
#                       <div class="col-7 text-muted">
#                         Al-Ahqaf
#                       </div>
#                       <div class="col-3">
#                         الأحقاف
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Wind-Curved Sandhills
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="47 muhammad muhammad محمد">
#                   <a href="/47">
#                     <div class='row'>
#                       <div class="col-2">47</div>
#                       <div class="col-7 text-muted">
#                         Muhammad
#                       </div>
#                       <div class="col-3">
#                         محمد
#                       </div>
#                       <div class="col-10 offset-2">
#                         Muhammad
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="48 al-fath the victory الفتح">
#                   <a href="/48">
#                     <div class='row'>
#                       <div class="col-2">48</div>
#                       <div class="col-7 text-muted">
#                         Al-Fath
#                       </div>
#                       <div class="col-3">
#                         الفتح
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Victory
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="49 al-hujurat the rooms الحجرات">
#                   <a href="/49">
#                     <div class='row'>
#                       <div class="col-2">49</div>
#                       <div class="col-7 text-muted">
#                         Al-Hujurat
#                       </div>
#                       <div class="col-3">
#                         الحجرات
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Rooms
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="50 qaf the letter &quot;qaf&quot; ق">
#                   <a href="/50">
#                     <div class='row'>
#                       <div class="col-2">50</div>
#                       <div class="col-7 text-muted">
#                         Qaf
#                       </div>
#                       <div class="col-3">
#                         ق
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Letter &quot;Qaf&quot;
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="51 adh-dhariyat the winnowing winds الذاريات">
#                   <a href="/51">
#                     <div class='row'>
#                       <div class="col-2">51</div>
#                       <div class="col-7 text-muted">
#                         Adh-Dhariyat
#                       </div>
#                       <div class="col-3">
#                         الذاريات
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Winnowing Winds
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="52 at-tur the mount الطور">
#                   <a href="/52">
#                     <div class='row'>
#                       <div class="col-2">52</div>
#                       <div class="col-7 text-muted">
#                         At-Tur
#                       </div>
#                       <div class="col-3">
#                         الطور
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Mount
#                       </div>
#                     </div>
# </a>                </div>
#                 <div class="dropdown-item " data-filter-tags="53 an-najm the star النجم">
#                   <a href="/53">
#                     <div class='row'>
#                       <div class="col-2">53</div>
#                       <div class="col-7 text-muted">
#                         An-Najm
#                       </div>
#                       <div class="col-3">
#                         النجم
#                       </div>
#                       <div class="col-10 offset-2">
#                         The Star
#                       </div>
#                     </div>
# </a>                </div>
# ...
#     </div>
#
#     <div class="col-11">
#       <div class="arabic text-right code">
#           <span class="word w" id="w-6844" data-local='english' data-audio="wbw/001_006_001.mp3" data-t="Guide us" data-tr="ih&#39;dinā" data-position="1" data-key="1:6:1" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb67;
#   </span>
# </span>
# <span class="word w" id="w-6845" data-local='english' data-audio="wbw/001_006_002.mp3" data-t="(to) the path" data-tr="l-ṣirāṭa" data-position="2" data-key="1:6:2" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb68;
#   </span>
# </span>
# <span class="word w" id="w-6846" data-local='english' data-audio="wbw/001_006_003.mp3" data-t="the straight" data-tr="l-mus&#39;taqīma" data-position="3" data-key="1:6:3" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb69;
#   </span>
# </span>
# <span class="end w" id="w-6847" data-local='english' data-audio="" data-t="Ayah 6" data-tr="" data-position="4" data-key="" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6a;
#   </span>
# </span>
#
#       </div>
#     </div>
#   </div>
#
#   <div class="row verse-actions-below">
#     <div class="col-md-1 order-1 order-md-0">
#       <div class="d-flex flex-md-column justify-content-between justify-content-md-center align-items-center py-2 py-md-0 flex-wrap">
#         <a
#           class="play ayah-action my-3 text-muted text-center"
#           data-title="Play"
#           data-controller="track"
#           data-name='ayah-action'
#           data-category="play"
#         >
#
#           <i class="fa fa-play-circle h4"></i>
#           <small class="d-md-none d-block ff-r">
#             <span class='en'>Play</span>
#           </small>
#         </a>
#
#         <a class="ayah-action copy my-3 text-muted text-center"
#            data-title="Copy"
#            data-done="Copied!"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="copy">
#           <i class="fa fa-copy"></i>
#           <small class="d-md-none d-block ff-r mt-2">
#             <span class='en'>Copy</span>
#           </small>
#         </a>
#
#         <a class="ayah-action my-3 text-muted text-center"
#            data-title="Tafsirs"
#            data-controller="ajax-modal"
#            data-url="/verses/6/select_tafsirs"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="tafsir-list">
#           <i class="fa fa-book"></i>
#           <small class="d-md-none d-block ff-r mt-2">Tafsirs</small>
#         </a>
#
#         <a href="#"
#            class="ayah-action my-3 text-muted text-center"
#            data-title="Share"
#            data-controller="ajax-modal"
#            data-url="/verses/6/share"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="share-list">
#           <i class="fa fa-share-alt"></i>
#           <small class="d-md-none d-block ff-r mt-2">
#             Share
#           </small>
#         </a>
#
#         <a class="ayah-action text-center text-muted my-2 reflection-link"
#            data-title="Read Reflections for this Ayah on QuranReflect"
#            href="http://quranreflect.com/1/6?feed=true" target="_blank"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="QuranReflect">
#           <img width="30" data-src="https://cdn.qurancdn.com/assets/icon/QR-icon-b0946a40331951abe50fd9e2b02a7016b561c641c34a6c06f064e2beddd1cf6e.png" class=" lazyload" src="..." />
#           <small class="d-md-none d-block ff-r mt-2">QuranReflect</small>
#         </a>
#       </div>
#     </div>
#
#     <div class="col-md-11">
#       <div class="translation">
#           <div class="text-muted mt-5 mb-2 english"
#      id="translation_903963"
#      data-controller="translation">
#
#   Guide us along the Straight Path,
#
#   <small class="d-block resource"> Dr. Mustafa Khattab, the Clear Quran
# </small>
#   <div id="footnotes"></div>
# </div>
#
#       </div>
#     </div>
#   </div>
# </div>
# <div class="verse p-3 my-3 border-bottom"
#      id="7"
#      data-verse-number="7"
#      data-controller="verse"
#      data-key="1:7"
#      data-text="صِرَٰطَ ٱلَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ ٱلْمَغْضُوبِ عَلَيْهِمْ وَلَا ٱلضَّآلِّينَ"
# >
#   <div class="row">
#     <div class="col-1 verse-actions-below-above text-center">
#         <a target="blank" class="badge bg-secondary p-1" href="/1/7?translations=131">1:7</a>
#     </div>
#
#     <div class="col-11">
#       <div class="arabic text-right code">
#           <span class="word w" id="w-8411" data-local='english' data-audio="wbw/001_007_001.mp3" data-t="(The) path" data-tr="ṣirāṭa" data-position="1" data-key="1:7:1" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6b;
#   </span>
# </span>
# <span class="word w" id="w-8412" data-local='english' data-audio="wbw/001_007_002.mp3" data-t="(of) those" data-tr="alladhīna" data-position="2" data-key="1:7:2" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6c;
#   </span>
# </span>
# <span class="word w" id="w-8413" data-local='english' data-audio="wbw/001_007_003.mp3" data-t="You have bestowed (Your) Favors" data-tr="anʿamta" data-position="3" data-key="1:7:3" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6d;
#   </span>
# </span>
# <span class="word w" id="w-8414" data-local='english' data-audio="wbw/001_007_004.mp3" data-t="on them" data-tr="ʿalayhim" data-position="4" data-key="1:7:4" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6e;
#   </span>
# </span>
# <span class="word w" id="w-8415" data-local='english' data-audio="wbw/001_007_005.mp3" data-t="not (of)" data-tr="ghayri" data-position="5" data-key="1:7:5" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb6f;
#   </span>
# </span>
# <span class="word w" id="w-8416" data-local='english' data-audio="wbw/001_007_006.mp3" data-t="those who earned (Your) wrath" data-tr="l-maghḍūbi" data-position="6" data-key="1:7:6" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb70;
#   </span>
# </span>
# <span class="word w" id="w-8417" data-local='english' data-audio="wbw/001_007_007.mp3" data-t="on themselves" data-tr="ʿalayhim" data-position="7" data-key="1:7:7" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb71;
#   </span>
# </span>
# <span class="word w" id="w-8418" data-local='english' data-audio="wbw/001_007_008.mp3" data-t="and not" data-tr="walā" data-position="8" data-key="1:7:8" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb72;
#   </span>
# </span>
# <span class="word w" id="w-8419" data-local='english' data-audio="wbw/001_007_009.mp3" data-t="(of) those who go astray" data-tr="l-ḍālīna" data-position="9" data-key="1:7:9" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb73;
#   </span>
# </span>
# <span class="end w" id="w-8420" data-local='english' data-audio="" data-t="Ayah 7" data-tr="" data-position="10" data-key="" data-controller="word">
#   <span class="p1-v1 v1">
#     &#xfb74;
#   </span>
# </span>
#
#       </div>
#     </div>
#   </div>
#
#   <div class="row verse-actions-below">
#     <div class="col-md-1 order-1 order-md-0">
#       <div class="d-flex flex-md-column justify-content-between justify-content-md-center align-items-center py-2 py-md-0 flex-wrap">
#         <a
#           class="play ayah-action my-3 text-muted text-center"
#           data-title="Play"
#           data-controller="track"
#           data-name='ayah-action'
#           data-category="play"
#         >
#
#           <i class="fa fa-play-circle h4"></i>
#           <small class="d-md-none d-block ff-r">
#             <span class='en'>Play</span>
#           </small>
#         </a>
#
#         <a class="ayah-action copy my-3 text-muted text-center"
#            data-title="Copy"
#            data-done="Copied!"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="copy">
#           <i class="fa fa-copy"></i>
#           <small class="d-md-none d-block ff-r mt-2">
#             <span class='en'>Copy</span>
#           </small>
#         </a>
#
#         <a class="ayah-action my-3 text-muted text-center"
#            data-title="Tafsirs"
#            data-controller="ajax-modal"
#            data-url="/verses/7/select_tafsirs"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="tafsir-list">
#           <i class="fa fa-book"></i>
#           <small class="d-md-none d-block ff-r mt-2">Tafsirs</small>
#         </a>
#
#         <a href="#"
#            class="ayah-action my-3 text-muted text-center"
#            data-title="Share"
#            data-controller="ajax-modal"
#            data-url="/verses/7/share"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="share-list">
#           <i class="fa fa-share-alt"></i>
#           <small class="d-md-none d-block ff-r mt-2">
#             Share
#           </small>
#         </a>
#
#         <a class="ayah-action text-center text-muted my-2 reflection-link"
#            data-title="Read Reflections for this Ayah on QuranReflect"
#            href="http://quranreflect.com/1/7?feed=true" target="_blank"
#            data-controller="track"
#            data-name='ayah-action'
#            data-category="QuranReflect">
#           <img width="30" data-src="https://cdn.qurancdn.com/assets/icon/QR-icon-b0946a40331951abe50fd9e2b02a7016b561c641c34a6c06f064e2beddd1cf6e.png" class=" lazyload" src="..." />
#           <small class="d-md-none d-block ff-r mt-2">QuranReflect</small>
#         </a>
#       </div>
#     </div>
#
#     <div class="col-md-11">
#       <div class="translation">
#           <div class="text-muted mt-5 mb-2 english"
#      id="translation_903964"
#      data-controller="translation">
#
#   the Path of those You have blessed—not those You are displeased with, or those who are astray.<sup foot_note=76374>1</sup>
#
#   <small class="d-block resource"> Dr. Mustafa Khattab, the Clear Quran
# </small>
#   <div id="footnotes"></div>
# </div>
#
#       </div>
#     </div>
#   </div>
# </div>
#
#
# <div class="text-center my-3 pagination" id="verses-translation_pagination" data-url="/1">
#
#
#
#     <a class="btn btn-outline-primary mt-4" href="/1?reading=false">
#       <span class='en'>Beginning of Surah</span>
# </a>
#     <a class="btn btn-outline-primary mt-4" href="/2?reading=false">
#       <span class='en'>Next Surah</span>
# </a></div>
#
#         </div>
#       </div>
#     </div>
#
#     <div class="tab-pane fade " id="pill-reading" role="tabpanel" aria-labelledby="pill-reading-tab">
#
#       <div id="verses-reading" class='verses' data-controller="infinite-page" data-items-container="#verses-reading #verses">
#         <div id='verses'>
#
# <div class="render-async  " id="render_async_acb4e0d8cc1606535251" data-path="/1?reading=true" data-method="GET" data-headers="{}" data-lazy-load="{&quot;root&quot;:&quot;#pill-reading&quot;}" data-controller="render-async">
#
#               <p class="text-center p-3">
#                 <i class='fa fa-spinner fa-spin'></i> <span class='en'>Loading...</span>
#               </p>
#
# </div>        </div>
#       </div>
#     </div>
#
#     <div class="tab-pane fade" id="pill-info" role="tabpanel" aria-labelledby="pill-info-tab">
#
# <div class="render-async  " id="render_async_2fcbee039c1606535251" data-path="/chapter_info/1" data-method="GET" data-headers="{}" data-lazy-load="{&quot;root&quot;:&quot;#pill-info&quot;}" data-controller="render-async">
#
#         <p class="text-center p-3">
#           <i class='fa fa-spinner fa-spin'></i> <span class='en'>Loading...</span>
#         </p>
#
# </div>    </div>
#   </div>
#
#   <div id="player" data-controller="player player-manager" class="fixed-bottom bg-white custom-shadow">
#   <div class="container p-2">
#     <div class="row offset-md-2">
#       <div class="col-md-3 d-flex justify-content-between mt-3 order-md-0 order-1">
#         <div class="previous-btn d-flex align-items-center order-md-0 order-2">
#           <i class="fa-center-3 text-muted fa fa-step-backward c-pointer"></i>
#         </div>
#
#         <div class="d-flex align-items-center order-md-1 order-3" style="font-size: 30px">
#           <i class="fa-center-3 text-primary fa-play-circle c-pointer play-btn"></i>
#         </div>
#
#         <div class="next-btn d-flex align-items-center order-md-2 order-4">
#           <i class="fa-center-3 text-muted fa fa-step-forward c-pointer"></i>
#         </div>
#
#         <div class="d-flex align-items-center order-md-3 order-5">
#           <i
#             class="fa-center-3 text-muted fa fa-link-regular c-pointer"
#             id="auto-scroll-btn"
#             data-title="<span class='en'>Automatically scrolls to the currently playing ayah</span>"
#           ></i>
#         </div>
#       </div>
#
#       <div class="col-12 col-md-8 d-flex align-items-center">
#         <small class="text-primary timer mr-3 d-none">00:00</small>
#         <div id="player-bar">
#           <input type="range" min="1" max="100" step="0.1" value="0" disabled class="player-bar__range" id="player-range">
#         </div>
#         <small class="text-primary total-time ml-2 d-none">00:00</small>
#       </div>
#     </div>
#   </div>
# </div>
#
# </div>
#
#     </main>
#
#     <footer class="footer pb-5">
#   <div class="container">
#     <div class="row">
#       <div class="col-lg-2 col-md-3 col-sm-6">
#         <div class="footer-tab">
#           <h4><span class='en'>Navigate</span></h4>
#           <ul>
#             <li>
#               <a href="/about-us"><span class='en'>About us</span></a>
#             </li>
#             <li>
#               <a href="/donations"><span class='en'>Contribute</span></a>
#             </li>
#             <li>
#               <a href="/support"><span class='en'>Help & feedback</span></a>
#             </li>
#             <li>
#               <a href="/developers"><span class='en'>Developers</span></a>
#             </li>
#             <li>
#               <a href="/apps"><span class='en'>Download</span></a>
#             </li>
#           </ul>
#         </div>
#       </div>
#
#       <div class="col-lg-2 col-md-3 col-sm-6">
#         <div class="footer-tab">
#           <h4><span class='en'>Useful sites</span></h4>
#           <ul>
#             <li>
#               <a href="https://quranicaudio.com/" target="_blank" rel="noopener noreferrer">Quraninaudio.com</a>
#             </li>
#             <li>
#               <a href="https://salah.com/" target="_blank" rel="noopener noreferrer">Salah.com</a>
#             </li>
#             <li>
#               <a href="https://sunnah.com/" target="_blank" rel="noopener noreferrer">Sunnah.com</a>
#             </li>
#             <li>
#               <a href="https://legacy.quran.com/" target="_blank" rel="noopener noreferrer"> Legacy Quran.com</a>
#             </li>
#             <li>
#               <a href="https://corpus.quran.com/wordbyword.jsp" target="_blank" rel="noopener noreferrer">Corpus.Quran.com</a>
#             </li>
#           </ul>
#         </div>
#       </div>
#
#       <div class="col-lg-2 col-md-3 col-sm-6">
#         <div class="footer-tab">
#           <h4><span class='en'>Other links</span></h4>
#           <ul>
#             <li>
#               <a href="https://quran.com/sitemap.xml.gz" target="_blank" rel="noopener noreferrer">Sitemap</a>
#             </li>
#             <li>
#               <a href="https://quran.com/36" target="_blank" rel="noopener noreferrer">Surah Yaseen (يس)</a>
#             </li>
#             <li>
#               <a href="https://quran.com/2/255" target="_blank" rel="noopener noreferrer">Ayat Al-Kursi (آية الكرسي)</a>
#             </li>
#           </ul>
#         </div>
#       </div>
#
#       <div class="col-lg-4 col-md-6 col-sm-12 ml-auto">
#         <div class="copyright">
#           <p class="mb-4">
#             <span class='en'>Quran.com is a Sadaqah Jariyah. We hope to make it easy for everyone to read, study, and learn The Noble Quran. The Noble Quran has many names including Al-Quran Al-Kareem, Al-Ketab, Al-Furqan, Al-Maw'itha, Al-Thikr, and Al-Noor.</span>
#           </p>
#           <p class="mb-0">&copy; 2020 <a href="https://quran.com">Quran.com</a>. <span class='en'>All Rights Reserved</span></p>
#         </div>
#       </div>
#     </div>
#   </div>
# </footer>
#
#   </body>
# </html>

# %%
soup = BeautifulSoup(web_data.text,'html.parser')

# %%
find_word = soup.find_all("h2",{"class":"text-left text-translation times-new"})

for i in find_word:
    print(i)

# %%
import http.client

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#                name  index                                              verse  \
# verse_1  al-Fatihah      1    In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1              Praise be to God, Lord of the Worlds.
# verse_3  al-Fatihah      1              The Most Gracious, the Most Merciful.
# verse_4  al-Fatihah      1                     Master of the Day of Judgment.
# verse_5  al-Fatihah      1  It is You we worship, and upon You we call for...
# verse_6  al-Fatihah      1                     Guide us to the straight path.
# verse_7  al-Fatihah      1  The path of those You have blessed, not of tho...
#
#          count
# verse_1      7
# verse_2      7
# verse_3      7
# verse_4      7
# verse_5      7
# verse_6      7
# verse_7      7

# %%
data
# Out:
#                name  index                                              verse  \
# verse_1  al-Fatihah      1    In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1              Praise be to God, Lord of the Worlds.
# verse_3  al-Fatihah      1              The Most Gracious, the Most Merciful.
# verse_4  al-Fatihah      1                     Master of the Day of Judgment.
# verse_5  al-Fatihah      1  It is You we worship, and upon You we call for...
# verse_6  al-Fatihah      1                     Guide us to the straight path.
# verse_7  al-Fatihah      1  The path of those You have blessed, not of tho...
#
#          count
# verse_1      7
# verse_2      7
# verse_3      7
# verse_4      7
# verse_5      7
# verse_6      7
# verse_7      7

# %%
data.describe()
# Out:
#        index  count
# count    7.0    7.0
# mean     1.0    7.0
# std      0.0    0.0
# min      1.0    7.0
# 25%      1.0    7.0
# 50%      1.0    7.0
# 75%      1.0    7.0
# max      1.0    7.0

# %%
data.columns
# Out:
# Index(['name', 'index', 'verse', 'count'], dtype='object')

# %%
data.drop(['name','index','count'],axis=1,inplace=True)
data
# Out:
#                                                      verse
# verse_1    In the name of God, the Gracious, the Merciful.
# verse_2              Praise be to God, Lord of the Worlds.
# verse_3              The Most Gracious, the Most Merciful.
# verse_4                     Master of the Day of Judgment.
# verse_5  It is You we worship, and upon You we call for...
# verse_6                     Guide us to the straight path.
# verse_7  The path of those You have blessed, not of tho...

# %%
verse_df['verse']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-da6a88ed3e11> in <module>
# ----> 1 verse_df['verse']
#
# NameError: name 'verse_df' is not defined

# %%
data.shape
# Out:
# (6236, 3)

# %%
verses = verse_df['verse'].str.split("_", n=1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7b860a760a7a> in <module>
# ----> 1 verses = verse_df['verse'].str.split("_", n=1, expand=True)
#
# NameError: name 'verse_df' is not defined

# %%
data['verse']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'verse'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-1548d509ecb3> in <module>
# ----> 1 data['verse']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'verse'

# %%
verses = data['verse'].str.split("_", n=1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'verse'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-8a80c07f2f55> in <module>
# ----> 1 verses = data['verse'].str.split("_", n=1, expand=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'verse'

# %%
verses.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-4451e471d081> in <module>
# ----> 1 verses.head()
#
# NameError: name 'verses' is not defined

# %%
verses.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-4451e471d081> in <module>
# ----> 1 verses.head()
#
# NameError: name 'verses' is not defined

# %%
url = "https://quran.com/1"

# %%
web_data = requests.get(url)

# %%
data2 = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-english/en_translation_1.json')

# %%
data2
# Out:
#                name  index                                              verse  \
# verse_1  al-Fatihah      1    In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1              Praise be to God, Lord of the Worlds.
# verse_3  al-Fatihah      1              The Most Gracious, the Most Merciful.
# verse_4  al-Fatihah      1                     Master of the Day of Judgment.
# verse_5  al-Fatihah      1  It is You we worship, and upon You we call for...
# verse_6  al-Fatihah      1                     Guide us to the straight path.
# verse_7  al-Fatihah      1  The path of those You have blessed, not of tho...
#
#          count
# verse_1      7
# verse_2      7
# verse_3      7
# verse_4      7
# verse_5      7
# verse_6      7
# verse_7      7

# %%
data2.columns
# Out:
# Index(['name', 'index', 'verse', 'count'], dtype='object')

# %%
data.drop(['name','index','count'],axis=1,inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-887d2201535d> in <module>
# ----> 1 data.drop(['name','index','count'],axis=1,inplace=True)
#       2 data
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['name' 'index' 'count'] not found in axis"

# %%
def remove_punctuation(text):
    no_punct = "".join([c for c in text if c not in string.punctuation])
    return no_punct

# %%
data2['verse']
# Out:
# verse_1      In the name of God, the Gracious, the Merciful.
# verse_2                Praise be to God, Lord of the Worlds.
# verse_3                The Most Gracious, the Most Merciful.
# verse_4                       Master of the Day of Judgment.
# verse_5    It is You we worship, and upon You we call for...
# verse_6                       Guide us to the straight path.
# verse_7    The path of those You have blessed, not of tho...
# Name: verse, dtype: object

# %%
data2['verse']=data2['verse'].apply(lambda x: remove_punctuation)

# %%
data2['verse'].head()
# Out:
# verse_1    <function remove_punctuation at 0x1a1ba19680>
# verse_2    <function remove_punctuation at 0x1a1ba19680>
# verse_3    <function remove_punctuation at 0x1a1ba19680>
# verse_4    <function remove_punctuation at 0x1a1ba19680>
# verse_5    <function remove_punctuation at 0x1a1ba19680>
# Name: verse, dtype: object

# %%
data3 = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-english/en_translation_1.json')

# %%
data3
# Out:
#                name  index                                              verse  \
# verse_1  al-Fatihah      1    In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1              Praise be to God, Lord of the Worlds.
# verse_3  al-Fatihah      1              The Most Gracious, the Most Merciful.
# verse_4  al-Fatihah      1                     Master of the Day of Judgment.
# verse_5  al-Fatihah      1  It is You we worship, and upon You we call for...
# verse_6  al-Fatihah      1                     Guide us to the straight path.
# verse_7  al-Fatihah      1  The path of those You have blessed, not of tho...
#
#          count
# verse_1      7
# verse_2      7
# verse_3      7
# verse_4      7
# verse_5      7
# verse_6      7
# verse_7      7

# %%
data3.drop(['name','index','count'],axis=1,inplace=True)
data
# Out:
#       surah_number  verse_number  \
# 0                1             1
# 1                1             2
# 2                1             3
# 3                1             4
# 4                1             5
# ...            ...           ...
# 6231           114             2
# 6232           114             3
# 6233           114             4
# 6234           114             5
# 6235           114             6
#
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 3 columns]

# %%
data3['verse']=data3['verse'].apply(lambda x: remove_punctuation)

# %%
data3['verse'].head()
# Out:
# verse_1    <function remove_punctuation at 0x1a1ba19680>
# verse_2    <function remove_punctuation at 0x1a1ba19680>
# verse_3    <function remove_punctuation at 0x1a1ba19680>
# verse_4    <function remove_punctuation at 0x1a1ba19680>
# verse_5    <function remove_punctuation at 0x1a1ba19680>
# Name: verse, dtype: object

# %%
data4 = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-english/en_translation_1.json')

# %%
data4.drop(['name','index','count'],axis=1,inplace=True)
data
# Out:
#       surah_number  verse_number  \
# 0                1             1
# 1                1             2
# 2                1             3
# 3                1             4
# 4                1             5
# ...            ...           ...
# 6231           114             2
# 6232           114             3
# 6233           114             4
# 6234           114             5
# 6235           114             6
#
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 3 columns]

# %%
data4['verse']=data4['verse'].apply(lambda x:lower()))
# Out:
#   File "<ipython-input-67-7ed12a15bf4e>", line 1
#     data4['verse']=data4['verse'].apply(lambda x:lower()))
#                                                          ^
# SyntaxError: invalid syntax

# %%
tokenizer=RegexpTokenizer(r'\wt')

# %%
data4['verse'] = data4['verse'].apply(lambda x: tokenizer.tokenize(x.lower()))

# %%
data4['verse'].head()
# Out:
# verse_1          []
# verse_2          []
# verse_3    [st, st]
# verse_4    [st, nt]
# verse_5        [it]
# Name: verse, dtype: object

# %%
data5 = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/notebook/eda/Suraiya-Project/English.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-553e1a50599d> in <module>
# ----> 1 data5 = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/notebook/eda/Suraiya-Project/English.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     737         obj = None
#     738         if typ == "frame":
# --> 739             obj = FrameParser(json, **kwargs).parse()
#     740
#     741         if typ == "series" or obj is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     847
#     848         else:
# --> 849             self._parse_no_numpy()
#     850
#     851         if self.obj is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1091         if orient == "columns":
#    1092             self.obj = DataFrame(
# -> 1093                 loads(json, precise_float=self.precise_float), dtype=None
#    1094             )
#    1095         elif orient == "split":
#
# ValueError: Trailing data

# %%
data6 = pd.read_json('https://raw.githubusercontent.com/risan/quran-json/master/json/translations/en.pretty.json')

# %%
data6.head()
# Out:
#    surah_number  verse_number  \
# 0             1             1
# 1             1             2
# 2             1             3
# 3             1             4
# 4             1             5
#
#                                              content
# 0  In the name of Allah, the Entirely Merciful, t...
# 1  [All] praise is [due] to Allah, Lord of the wo...
# 2    The Entirely Merciful, the Especially Merciful,
# 3                Sovereign of the Day of Recompense.
# 4      It is You we worship and You we ask for help.

# %%
data6.describe()
# Out:
#        surah_number  verse_number
# count   6236.000000   6236.000000
# mean      33.519724     53.506575
# std       26.461261     50.463924
# min        1.000000      1.000000
# 25%       11.000000     16.000000
# 50%       26.000000     38.000000
# 75%       51.000000     75.000000
# max      114.000000    286.000000

# %%
data6.columns
# Out:
# Index(['surah_number', 'verse_number', 'content'], dtype='object')

# %%
data6.drop(['surah_number','verse_number'],axis=1,inplace=True)

# %%
data6
# Out:
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 1 columns]

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 1 columns):
# content    6236 non-null object
# dtypes: object(1)
# memory usage: 48.8+ KB

# %%
data6.describe()
# Out:
#                                                   content
# count                                                6236
# unique                                               6111
# top     So which of the favors of your Lord would you ...
# freq                                                   24

# %%
data7 = pd.read_json('https://raw.githubusercontent.com/risan/quran-json/master/json/translations/en.pretty.json')

# %%
data7.head()
# Out:
#    surah_number  verse_number  \
# 0             1             1
# 1             1             2
# 2             1             3
# 3             1             4
# 4             1             5
#
#                                              content
# 0  In the name of Allah, the Entirely Merciful, t...
# 1  [All] praise is [due] to Allah, Lord of the wo...
# 2    The Entirely Merciful, the Especially Merciful,
# 3                Sovereign of the Day of Recompense.
# 4      It is You we worship and You we ask for help.

# %%
data7.columns
# Out:
# Index(['surah_number', 'verse_number', 'content'], dtype='object')

# %%
data7.drop(['surah_number','verse_number'],axis=1,inplace=True)
data7
# Out:
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 1 columns]

# %%
data7.head(100)
# Out:
#                                               content
# 0   In the name of Allah, the Entirely Merciful, t...
# 1   [All] praise is [due] to Allah, Lord of the wo...
# 2     The Entirely Merciful, the Especially Merciful,
# 3                 Sovereign of the Day of Recompense.
# 4       It is You we worship and You we ask for help.
# ..                                                ...
# 95  And when there came to them a Book from Allah ...
# 96  How wretched is that for which they sold thems...
# 97  And when it is said to them, "Believe in what ...
# 98  And Moses had certainly brought you clear proo...
# 99  And [recall] when We took your covenant and ra...
#
# [100 rows x 1 columns]

# %%
tokenizer=RegexpTokenizer(r'\wt')

# %%
data7.rename(columns={'content':'translation'},inplace=True)

# %%
data7
# Out:
#                                             translation
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 1 columns]

# %%
data7
# Out:
#      translation
# 0           [nt]
# 1             []
# 2           [nt]
# 3             []
# 4           [it]
# ...          ...
# 6231          []
# 6232          []
# 6233    [et, at]
# 6234    [nt, st]
# 6235          []
#
# [6236 rows x 1 columns]

# %%
data7['translation'].head()
# Out:
# 0    [nt]
# 1      []
# 2    [nt]
# 3      []
# 4    [it]
# Name: translation, dtype: object

# %%
data6.head()
# Out:
#                                              content
# 0  In the name of Allah, the Entirely Merciful, t...
# 1  [All] praise is [due] to Allah, Lord of the wo...
# 2    The Entirely Merciful, the Especially Merciful,
# 3                Sovereign of the Day of Recompense.
# 4      It is You we worship and You we ask for help.

# %%
data6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1d68e70382ef> in <module>
# ----> 1 data6
#
# NameError: name 'data6' is not defined

# %%
from nltk.tokenize import word_tokenize

# %%
text = "In the Name of Allah the Most Compassionate, Most Merciful."

# %%
print(word_tokenize(text))
# Out:
# ['In', 'the', 'Name', 'of', 'Allah', 'the', 'Most', 'Compassionate', ',', 'Most', 'Merciful', '.']

# %%
print(word_tokenize(text))
# Out:
# ['In', 'the', 'Name', 'of', 'Allah', 'the', 'Most', 'Compassionate', ',', 'Most', 'Merciful', '.']

# %%
import nltk
 nltk.download('punkt')
# Out:
#   File "<ipython-input-52-16b5369c7a8a>", line 2
#     nltk.download('punkt')
#     ^
# IndentationError: unexpected indent

# %%
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/suraiya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(word_tokenize(text))
# Out:
# ['In', 'the', 'Name', 'of', 'Allah', 'the', 'Most', 'Compassionate', ',', 'Most', 'Merciful', '.']

# %%
s1 = "In the Name of Allah the Most Compassionate, Most Merciful."

# %%
word_tokenize(s1)
# Out:
# ['In',
#  'the',
#  'Name',
#  'of',
#  'Allah',
#  'the',
#  'Most',
#  'Compassionate',
#  ',',
#  'Most',
#  'Merciful',
#  '.']

# %%
s1.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a20659c8f85> in <module>
# ----> 1 s1.describe()
#
# NameError: name 's1' is not defined
