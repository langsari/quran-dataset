# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_json('https://raw.githubusercontent.com/namnamir/Parsing_Quran/master/Quran.json')

# %%
data
# Out:
#                                                               1     \
# Ayat_Audio_ar                                             1_ar.ogg
# Ayat_Audio_en                                             1_en.ogg
# Ayat_Audio_fa                                             1_fa.ogg
# Ayat_Text_ar               ﻿بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ
# Ayat_Text_en     In the name of Allah, the Entirely Merciful, t...
# Ayat_Text_fa                           به نام خداوند رحمتگر مهربان
# Ayat_in_Surah                                                    1
# Juz                                                              1
# Number_of_Ayats                                                  7
# Surah_ID                                                         1
# Surah_Name_ar                                              الفاتحة
# Surah_Name_en                                           Al-Faatiha
#
#                                                               10    \
# ...

# %%
data.head()
# Out:
#                                                             1     \
# Ayat_Audio_ar                                           1_ar.ogg
# Ayat_Audio_en                                           1_en.ogg
# Ayat_Audio_fa                                           1_fa.ogg
# Ayat_Text_ar             ﻿بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ
# Ayat_Text_en   In the name of Allah, the Entirely Merciful, t...
#
#                                                             10    \
# Ayat_Audio_ar                                          10_ar.ogg
# Ayat_Audio_en                                          10_en.ogg
# Ayat_Audio_fa                                          10_fa.ogg
# Ayat_Text_ar   الَّذِينَ يُؤْمِنُونَ بِالْغَيْبِ وَيُقِيمُونَ...
# Ayat_Text_en   Who believe in the unseen, establish prayer, a...
#
#                                                             100   \
# Ayat_Audio_ar                                         100_ar.ogg
# ...

# %%
data.describe()
# Out:
#         1     10    100                                                1000  \
# count     12    12    12                                                 12
# unique    10    12    12                                                 12
# top        1   286   286  And between them will be a partition, and on [...
# freq       3     1     1                                                  1
#
#                                                      1001         1002  \
# count                                                  12           12
# unique                                                 12           12
# top     و چون چشمانشان به سوى دوزخيان گردانيده شود، مى...  1002_fa.ogg
# freq                                                    1            1
#
#                                                      1003  1004  1005  1006  \
# count                                                  12    12    12    12
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Ayat_Audio_ar to Surah_Name_en
# Columns: 6235 entries, 1 to 999
# dtypes: object(6235)
# memory usage: 584.6+ KB

# %%
data.T
# Out:
#      Ayat_Audio_ar Ayat_Audio_en Ayat_Audio_fa  \
# 1         1_ar.ogg      1_en.ogg      1_fa.ogg
# 10       10_ar.ogg     10_en.ogg     10_fa.ogg
# 100     100_ar.ogg    100_en.ogg    100_fa.ogg
# 1000   1000_ar.ogg   1000_en.ogg   1000_fa.ogg
# 1001   1001_ar.ogg   1001_en.ogg   1001_fa.ogg
# ...            ...           ...           ...
# 995     995_ar.ogg    995_en.ogg    995_fa.ogg
# 996     996_ar.ogg    996_en.ogg    996_fa.ogg
# 997     997_ar.ogg    997_en.ogg    997_fa.ogg
# 998     998_ar.ogg    998_en.ogg    998_fa.ogg
# 999     999_ar.ogg    999_en.ogg    999_fa.ogg
#
#                                            Ayat_Text_ar  \
# 1               ﻿بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ
# 10    الَّذِينَ يُؤْمِنُونَ بِالْغَيْبِ وَيُقِيمُونَ...
# 100   وَإِذْ أَخَذْنَا مِيثَاقَكُمْ وَرَفَعْنَا فَوْ...
# 1000  وَبَيْنَهُمَا حِجَابٌ ۚ وَعَلَى الْأَعْرَافِ ر...
# 1001  ۞ وَإِذَا صُرِفَتْ أَبْصَارُهُمْ تِلْقَاءَ أَص...
# ...
