# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk

# %%
data = pd.read_json('https://raw.githubusercontent.com/risan/quran-json/master/json/translations/en.pretty.json')

# %%
data
# Out:
#       surah_number  verse_number  \
# 0                1             1
# 1                1             2
# 2                1             3
# 3                1             4
# 4                1             5
# ...            ...           ...
# 6231           114             2
# 6232           114             3
# 6233           114             4
# 6234           114             5
# 6235           114             6
#
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 3 columns]

# %%
data
# Out:
#       surah_number  verse_number  \
# 0                1             1
# 1                1             2
# 2                1             3
# 3                1             4
# 4                1             5
# ...            ...           ...
# 6231           114             2
# 6232           114             3
# 6233           114             4
# 6234           114             5
# 6235           114             6
#
#                                                 content
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 3 columns]

# %%
data.describe()
# Out:
#        surah_number  verse_number
# count   6236.000000   6236.000000
# mean      33.519724     53.506575
# std       26.461261     50.463924
# min        1.000000      1.000000
# 25%       11.000000     16.000000
# 50%       26.000000     38.000000
# 75%       51.000000     75.000000
# max      114.000000    286.000000

# %%
data.head(27)
# Out:
#     surah_number  verse_number  \
# 0              1             1
# 1              1             2
# 2              1             3
# 3              1             4
# 4              1             5
# 5              1             6
# 6              1             7
# 7              2             1
# 8              2             2
# 9              2             3
# 10             2             4
# 11             2             5
# 12             2             6
# 13             2             7
# 14             2             8
# 15             2             9
# 16             2            10
# 17             2            11
# 18             2            12
# 19             2            13
# 20             2            14
# 21             2            15
# 22             2            16
# 23             2            17
# 24             2            18
# 25             2            19
# 26             2            20
#
#                                               content
# 0   In the name of Allah, the Entirely Merciful, t...
# 1   [All] praise is [due] to Allah, Lord of the wo...
# 2     The Entirely Merciful, the Especially Merciful,
# 3                 Sovereign of the Day of Recompense.
# 4       It is You we worship and You we ask for help.
# 5                     Guide us to the straight path -
# 6   The path of those upon whom You have bestowed ...
# 7                                    Alif, Lam, Meem.
# 8   This is the Book about which there is no doubt...
# 9   Who believe in the unseen, establish prayer, a...
# 10  And who believe in what has been revealed to y...
# 11  Those are upon [right] guidance from their Lor...
# 12  Indeed, those who disbelieve - it is all the s...
# 13  Allah has set a seal upon their hearts and upo...
# 14  And of the people are some who say, "We believ...
# 15  They [think to] deceive Allah and those who be...
# 16  In their hearts is disease, so Allah has incre...
# 17  And when it is said to them, "Do not cause cor...
# 18  Unquestionably, it is they who are the corrupt...
# 19  And when it is said to them, "Believe as the p...
# 20  And when they meet those who believe, they say...
# 21  [But] Allah mocks them and prolongs them in th...
# 22  Those are the ones who have purchased error [i...
# 23  Their example is that of one who kindled a fir...
# 24  Deaf, dumb and blind - so they will not return...
# 25  Or [it is] like a rainstorm from the sky withi...
# 26  The lightning almost snatches away their sight...

# %%
data.rename(columns={'content':'translation'},inplace=True)

# %%
data
# Out:
#       surah_number  verse_number  \
# 0                1             1
# 1                1             2
# 2                1             3
# 3                1             4
# 4                1             5
# ...            ...           ...
# 6231           114             2
# 6232           114             3
# 6233           114             4
# 6234           114             5
# 6235           114             6
#
#                                             translation
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 3 columns):
# surah_number    6236 non-null int64
# verse_number    6236 non-null int64
# translation     6236 non-null object
# dtypes: int64(2), object(1)
# memory usage: 146.3+ KB
