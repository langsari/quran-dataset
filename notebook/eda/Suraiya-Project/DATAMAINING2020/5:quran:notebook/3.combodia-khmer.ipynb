# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/langsari/quran-dataset/master/notebook/eda/Suraiya-Project/rawdata/combodia-khmer-csv.csv')

# %%
data
# Out:
#      Translation Info:\n#---------------------------\n# Translation of the meanings of the Noble Qur'an\n# Language: Khmer\n# Translation ID: khmer_cambodia\n# Source: https://quranenc.com\n# URL: https://quranenc.com/en/browse/khmer_cambodia\n# Last update: 2017-02-18 (v1.0.0-csv.1)\n# Check for updates: https://quranenc.com/check/khmer_cambodia/v1.0.0-csv.1\n# PLEASE DON'T REMOVE THIS IMPORTANT INFORMATION!\n#---------------------------  \
# 0                                                    id
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 6232                                               6232
# 6233                                               6233
# 6234                                               6234
# 6235                                               6235
# 6236                                               6236
#
#      Unnamed: 1 Unnamed: 2                                         Unnamed: 3  \
# 0          sura        aya                                        translation
# 1             1          1          ក្នុងនាមអល់ឡោះមហាសប្បុរស មហាអាណិតស្រឡាញ់។
# 2             1          2  រាល់ការសរសើរ គឺចំពោះអល់ឡោះដែលជាម្ចាស់គ្រប់គ្រង...
# 3             1          3                ជាម្ចាស់មហាសប្បុរស មហាអាណិតស្រឡាញ់។
# 4             1          4          ជាសេ្ដច(គ្រប់គ្រង)នៃថ្ងៃជំនុំជំរះ(បរលោក)។
# ...         ...        ...                                                ...
# 6232        114          2                       ដែលជាសេ្ដចគ្រប់គ្រងមនុស្សលោក
# 6233        114          3                                ជាម្ចាស់នៃមនុស្សលោក
# 6234        114          4  ឱ្យបញ្ចៀសពីប្រការអាក្រក់នៃការញុះញង់របស់ ពួកស្ហៃតន
# 6235        114          5                  ដែលវាញុះញង់នៅក្នុងចិត្ដមនុស្សលោក។
# 6236        114          6                -(ស្ហៃតននោះ)មកអំពីជិន និងមនុស្សលោក។
#
#      Unnamed: 4
# 0     footnotes
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 6232        NaN
# 6233        NaN
# 6234        NaN
# 6235        NaN
# 6236        NaN
#
# [6237 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 5 columns):
# Translation Info:
# #---------------------------
# # Translation of the meanings of the Noble Qur'an
# # Language: Khmer
# # Translation ID: khmer_cambodia
# # Source: https://quranenc.com
# # URL: https://quranenc.com/en/browse/khmer_cambodia
# # Last update: 2017-02-18 (v1.0.0-csv.1)
# # Check for updates: https://quranenc.com/check/khmer_cambodia/v1.0.0-csv.1
# # PLEASE DON'T REMOVE THIS IMPORTANT INFORMATION!
# #---------------------------    6237 non-null object
# Unnamed: 1                                                                                                                                                                                                                                                                                                                                                                                                                                     6237 non-null object
# Unnamed: 2                                                                                                                                                                                                                                                                                                                                                                                                                                     6237 non-null object
# Unnamed: 3                                                                                                                                                                                                                                                                                                                                                                                                                                     6237 non-null object
# Unnamed: 4                                                                                                                                                                                                                                                                                                                                                                                                                                     1 non-null object
# dtypes: object(5)
# memory usage: 243.8+ KB

# %%
data.drop(['Unnamed: 4'],axis=1,inplace=True)

# %%
data
# Out:
#      Translation Info:\n#---------------------------\n# Translation of the meanings of the Noble Qur'an\n# Language: Khmer\n# Translation ID: khmer_cambodia\n# Source: https://quranenc.com\n# URL: https://quranenc.com/en/browse/khmer_cambodia\n# Last update: 2017-02-18 (v1.0.0-csv.1)\n# Check for updates: https://quranenc.com/check/khmer_cambodia/v1.0.0-csv.1\n# PLEASE DON'T REMOVE THIS IMPORTANT INFORMATION!\n#---------------------------  \
# 0                                                    id
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 6232                                               6232
# 6233                                               6233
# 6234                                               6234
# 6235                                               6235
# 6236                                               6236
#
#      Unnamed: 1 Unnamed: 2                                         Unnamed: 3
# 0          sura        aya                                        translation
# 1             1          1          ក្នុងនាមអល់ឡោះមហាសប្បុរស មហាអាណិតស្រឡាញ់។
# 2             1          2  រាល់ការសរសើរ គឺចំពោះអល់ឡោះដែលជាម្ចាស់គ្រប់គ្រង...
# 3             1          3                ជាម្ចាស់មហាសប្បុរស មហាអាណិតស្រឡាញ់។
# 4             1          4          ជាសេ្ដច(គ្រប់គ្រង)នៃថ្ងៃជំនុំជំរះ(បរលោក)។
# ...         ...        ...                                                ...
# 6232        114          2                       ដែលជាសេ្ដចគ្រប់គ្រងមនុស្សលោក
# 6233        114          3                                ជាម្ចាស់នៃមនុស្សលោក
# 6234        114          4  ឱ្យបញ្ចៀសពីប្រការអាក្រក់នៃការញុះញង់របស់ ពួកស្ហៃតន
# 6235        114          5                  ដែលវាញុះញង់នៅក្នុងចិត្ដមនុស្សលោក។
# 6236        114          6                -(ស្ហៃតននោះ)មកអំពីជិន និងមនុស្សលោក។
#
# [6237 rows x 4 columns]
