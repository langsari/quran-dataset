# %%
import pandas as pd
import numpy as numpy
import requests

# %%
print(f'pandas version:  {pd.__version__}')
print(f'requests version: {requests.__version__}')
# Out:
# pandas version:  0.25.1
# requests version: 2.22.0

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2020-09-29 12:32:25.737612')

# %%
url='http://destroyblackmagic.com/quran/data/th.thai.json'
r=requests.get(url)
j=r.json()
j
# Out:
# {'quran': {'th.thai': {'1': {'surah': 1,
#     'ayah': 1,
#     'verse': 'ด้วยพระนามของอัลลอฮฺ ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ'},
#    '2': {'surah': 1,
#     'ayah': 2,
#     'verse': 'การสรรเสริญทั้งหลายนั้น เป็นสิทธิของอัลลอฮฺผู้เป็นพระเจ้าแห่งสากลโลก'},
#    '3': {'surah': 1, 'ayah': 3, 'verse': 'ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ'},
#    '4': {'surah': 1, 'ayah': 4, 'verse': 'ผู้ทรงอภิสิทธิ์แห่งวันตอบแทน'},
#    '5': {'surah': 1,
#     'ayah': 5,
#     'verse': 'เฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์เคารพอิบาดะฮฺ และเฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์ขอความช่วยเหลือ'},
#    '6': {'surah': 1,
#     'ayah': 6,
#     'verse': 'ขอพระองค์ทรงแนะนำพวกข้าพระองค์ซึ่งทางอันเที่ยงตรง'},
#    '7': {'surah': 1,
#     'ayah': 7,
#     'verse': '(คือ) ทางของบรรดาผู้ที่พระองค์ได้ทรงโปรดปราณแก่พวกเขา มิใช่ในทางของพวกที่ถูกกริ้ว และมิใช่ทางของพวกที่หลงผิด'},
#    '8': {'surah': 2, 'ayah': 1, 'verse': 'อะลิฟ ลาม มีม'},
#    '9': {'surah': 2,
#     'ayah': 2,
# ...

# %%
type(j)
# Out:
# dict

# %%
df=pd.DataFrame(j)
df
# Out:
#                                                      quran
# th.thai  {'1': {'surah': 1, 'ayah': 1, 'verse': 'ด้วยพร...
