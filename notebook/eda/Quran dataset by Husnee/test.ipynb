# %%
import pandas as pd
import numpy as numpy
import requests

# %%
df = pd.read_csv("C:\laragon\www\quran-dataset\notebook\eda\Quran dataset by Husnee\csv\quran.csv")
df.head(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c0acfd4bff30> in <module>
# ----> 1 df = pd.read_csv("C:\laragon\www\quran-dataset\notebook\eda\Quran dataset by Husnee\csv\quran.csv")
#       2 df.head(s)
#
# NameError: name 'pd' is not defined

# %%
print(f'pandas version:  {pd.__version__}')
print(f'requests version: {requests.__version__}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-09f39a6d1d00> in <module>
# ----> 1 print(f'pandas version:  {pd.__version__}')
#       2 print(f'requests version: {requests.__version__}')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as numpy
import requests

# %%
print(f'pandas version:  {pd.__version__}')
print(f'requests version: {requests.__version__}')
# Out:
# pandas version:  1.0.5
# requests version: 2.24.0

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2020-11-26 16:01:39.972191')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set();

# %%
url='http://api.alquran.cloud/v1/quran/en.asad'
r=requests.get(url)
j=r.json()
j
# Out:
# py' state of life;",
#       'numberInSurah': 7,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6165,
#       'text': 'whereas he whose weight is light in the balance',
#       'numberInSurah': 8,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6166,
#       'text': 'shall be engulfed by an abyss.',
#       'numberInSurah': 9,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6167,
#       'text': 'And what could make thee conceive what that [abyss] will be?',
#       'numberInSurah': 10,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6168,
# ...

# %%
url='http://api.alquran.cloud/v1/quran/{{edition}}'
r=requests.get(url)
j=r.json()
j
# Out:
# : 240,
#       'sajda': False},
#      {'number': 6160,
#       'text': 'وَمَا أَدْرَاكَ مَا الْقَارِعَةُ',
#       'numberInSurah': 3,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6161,
#       'text': 'يَوْمَ يَكُونُ النَّاسُ كَالْفَرَاشِ الْمَبْثُوثِ',
#       'numberInSurah': 4,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6162,
#       'text': 'وَتَكُونُ الْجِبَالُ كَالْعِهْنِ الْمَنْفُوشِ',
#       'numberInSurah': 5,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
#       'sajda': False},
#      {'number': 6163,
#       'text': 'فَأَمَّا مَنْ ثَقُلَتْ مَوَازِينُهُ',
#       'numberInSurah': 6,
#       'juz': 30,
#       'manzil': 7,
#       'page': 600,
#       'ruku': 543,
#       'hizbQuarter': 240,
# ...

# %%
url=' http://api.alquran.cloud/v1/juz/{{juz}}/{{edition}}'
r=requests.get(url)
j=r.json()
j
# Out:
# {'code': 404,
#  'status': 'Not Found',
#  'data': 'Juz number should be betwen 1 and 30'}
