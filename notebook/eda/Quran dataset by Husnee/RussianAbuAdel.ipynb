# %%
import pandas as pd
import numpy as numpy
import requests

# %%
url = 'http://destroyblackmagic.com/quran/data/ru.abuadel.json'
df = pd.read_json(url)
df
# Out:
#                                                         quran
# ru.abuadel  {'1': {'surah': 1, 'ayah': 1, 'verse': 'С имен...

# %%
url='http://destroyblackmagic.com/quran/data/ru.abuadel.json'
r=requests.get(url)
j=r.json()
j
# Out:
# азались под милостью (Аллаха) [чтобы спаслись от вечного наказания в Аду]!'},
#    '945': {'surah': 6,
#     'ayah': 156,
#     'verse': '(И ниспослали Мы Коран для того), чтобы вам (о, неверующие из числа арабов) не говорить: «Книга ниспослана была только двум народам до нас [иудеям и христианам], и мы действительно были небрежны к ее изучению [не изучали их книг]».'},
#    '946': {'surah': 6,
#     'ayah': 157,
# ...
